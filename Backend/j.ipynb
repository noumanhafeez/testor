# %%
print("hkhkh")
# Out:
# hkhkh

# %%
# !pip install pandas
# Out:
# ...
#   Using cached pandas-2.3.3-cp313-cp313-macosx_10_13_x86_64.whl.metadata (91 kB)
# ...
#   Using cached numpy-2.4.0-cp313-cp313-macosx_14_0_x86_64.whl.metadata (6.6 kB)
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# ...
# Using cached pandas-2.3.3-cp313-cp313-macosx_10_13_x86_64.whl (11.5 MB)
# Using cached numpy-2.4.0-cp313-cp313-macosx_14_0_x86_64.whl (6.5 MB)
# Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# ...
#
# [notice] A new release of pip is available: 24.3.1 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
print("kjhkjh")
# Out:
# kjhkjh
